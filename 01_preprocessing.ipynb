# %% [markdown]
# <a href="https://colab.research.google.com/github/kjedrzejczak/Machine_Learning_Bootcamp_practice/blob/main/01_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
# Out:
# 1.23.5
# 1.5.3
# 1.2.2

# %% [markdown]
# ##Data

# %%
data = {'size' : ['Xl', 'L', 'M', 'L', 'M'],
        'color' : ['red', 'green', 'blue', 'green', 'red'],
        'gender': ['female', 'male', 'male', 'female', 'female'],
        'price': [199.0, 89.0, 99.0, 129.0, 79.0],
        'weight': [500, 450, 300, 300, 410],
        'gought': ['yes', 'no', 'yes', 'no', 'yes']}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight gought
# 0   Xl    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     300     no
# 4    M    red  female   79.0     410    yes

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   gought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
for i in ['size', 'color', 'gender', 'gought']:
  df[i] = df[i].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   gought  5 non-null      category
# dtypes: category(4), float64(1), int64(1)
# memory usage: 740.0 bytes

# %%
df.describe().T
# Out:
#         count   mean        std    min    25%    50%    75%    max
# price     5.0  119.0  48.476799   79.0   89.0   99.0  129.0  199.0
# weight    5.0  392.0  89.833179  300.0  300.0  410.0  450.0  500.0

# %%
df.describe(include='category').T
# Out:
#        count unique     top freq
# size       5      3       L    2
# color      5      3   green    2
# gender     5      2  female    3
# gought     5      2     yes    3
